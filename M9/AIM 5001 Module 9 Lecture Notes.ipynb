# %% [markdown]
# ## Module 8 Discussion Review
#
# "*For each of attributes 2 through 10, briefly explain what type of plot(s) you would recommend for their EDA and explain why you believe the plot(s) you’ve chosen will be the most appropriate for understanding each particular variable*."
#
# Attributes 2 - 10:
#
# __Season__ (1 = Spring; 2 = Summer; 3 = Autumn; 4 = Winter)
#
# - Categorical/Ordinal = bar plot
#
# __Hour__ (0 – 23: indicates the hour of the day)
#
# - Categorical / Ordinal = bar plot
#
# __Day of the week__ (Mon, Tue, Wed, Thu, Fri, Sat, Sun)
#
# - Categorical / Ordinal = bar plot
#
# __Weather__: (1 = Good; 2 =Mist or Fog; 3 = Light Precipitation (could be rain or snow); 4 = Heavy Precipitation (Rain, Snow, Ice Pellets)
#
# - Categorical / Ordinal = bar plot
#
# __Temperature__ in degrees Celsius
#
# - Continuous numeric = histogram + box plot
#
# __Humidity Level (0 – 100%)__
#
# - Continuous numeric = histogram + box plot
#
# __Windspeed__ in KM/Hr
#
# - Continuous numeric = histogram + box plot
#
#
# ### And finally, two tricky ones:
#
# __Number of casual users recorded as making use of the system during the indicated hour/day__
#
# - Number of casual users is numeric/discrete. So, for example, we could analyze the number of casual users using the bikeshare service on Tuesdays at 1pm using a histogram and boxplot.
#
# - However, other types of analysis (e.g., the relationship between day of the week and system usage) it might be more appropriate to use a bar plot, i.e., sum the number of casual users for each day of the week across all data records and then generate a bar plot wherein the x-axis is "Day of Week" and the y-axis is "Number of Casual Users"
#
# __Number of registered users recorded as making use of the system during the indicated hour/day__
#
# - Number of registered users is numeric/discrete. So, for example, we could analyze the number of registered users using the bikeshare service on Tuesdays at 1pm using a histogram and boxplot.
#
# - However, other types of analysis (e.g., the relationship between day of the week and system usage) it might be more appropriate to use a bar plot, i.e., sum the number of registered users for each day of the week across all data records and then generate a bar plot wherein the x-axis is "Day of Week" and the y-axis is "Number of Registered Users"
#
#
# ### What about scatter plots?
#
# - Scatter plots should be used when your are trying to visualize the relationships between two or more __numeric__ variables.
#
#
# ### When can I use a scatterplot for a categorical variable?
#
# - The short answer is "__never__"
#
# - For categorical variables, we can use __strip plots__ or __swarm plots__ (both are not truly "scatter plots") to visualize the relationships __between__ a categorical variable's values and numeric values:
#
# https://seaborn.pydata.org/tutorial/categorical.html
#
#
# ### What about line graphs?
#
# - Line graphs are appropriate for __time series__ numeric data, i.e., we want a plot of how the value of one or more variables changes relative to a chronological reference/indicator.
#
#
# ### How about pie charts?
#
# - Short answer: __never use pie charts for analytics work__. Pie charts are prone to misinterpretation due to the need for the human eye to try to discern differences in partial areas of a circle.
#
# https://www.businessinsider.com/pie-charts-are-the-worst-2013-6

# %% [markdown]
# # Module 8 Assignment Comments
#
#
# - Always double-check your work to __make sure that what you are submitting meets the stated requirements for the given Project or Assignment__.
#
#
# - When performing EDA work, __start by analyzing the distributions of the individual attributes BEFORE attempting to analyze any potential relationships between variables__. The summary statistics and distribution of each attribute should be analyzed + discussed. Why? As AI / Machine Learning / Analytics practitioners, we need to fully understand the characteristics of the distributions of each attribute we work with since __skew, multi-modality, outliers, etc. can all have a tangible impact on our downstream work__.
#
#
# - __When analyzing numeric attributes, both histograms and boxplots should be used__ (see M8 Lecture Notes), since each of these graphics provides a different perspective on the nature of the distribution of the attribute.
#
#
# - Always double-check the results of your analysis: Do your results make sense given what the raw data show? Do your graphics accurately reflect the data used to create them? etc.
#
#
# - Always double-check written content for spelling, capitalization, and grammar errors: your goal should be a "professional"-style deliverable.
#
#
# - Always double-check your Jupyter Notebook before submitting to ensure that graphics are displayed as you had expected and that Markdown cells are rendering as you had expected.

# %% [markdown]
# # Module 9: Working With Data from the Web
#
# ## Scraping a Web Site
#
# - Before we scrape a website, we __must__ examine the site's 'robots.txt' file to determine whether or not the site allows its content to be scraped.
#
#
# - To find the robots.txt file for a given web site, type in the base url and add “/robots.txt”. For example, if we wanted to scrape some data from apartments.com, type in https://www.apartments.com/robots.txt at the url box.
#
#
# - If the robots.txt allows full access the __Disallow__ field will be blank, e.g.:
#
# __User-agent: *__
#
# __Disallow:__
#
#
# - If the robots.txt blocks all access, the __Dissallow__ field will contain
# a backslash, e.g.:
#
# __User-agent: *__
#
# __Disallow: /__
#
#
# - If the robots.txt allows partial access, the prohibited and allowed sections will be identified with a pair of backslashes, e.g.,:
#
# __User-agent: *__
#
# __Disallow: /section/__
#
# __Allow: /section/__
#
#
# In the case of apartments.com, the robots.txt contains the following , as of today:
#
# https://www.apartments.com/robots.txt
#
#
# This tells us that we are __NOT__ allowed to scrape the 'services' and 'virtual-leasing-office' section(s) of that web site.
#
#
# If we examine Google's robots.txt we find that there is a long list of allowed and disallowed scraping activities:
#
# https://www.google.com/robots.txt
#
#
# ### Remember, you MUST check this for any web site you are interested in scraping. If the robots.txt tells you that scraping of either parts or the entirerty of the web site is prohibited, DO NOT SCRAPE ANY DATA FROM THE SPECIFIED SECTIONS OF THAT SITE.

# %% [markdown]
# ## How to Access Web Pages from your Python Code: 'urllib' vs. 'requests'
#
# - 'urllib' and 'requests' are two widely used Python libraries that facilitate the reading and sending of data from/to web pages.
#
#
# - 'urllib' is the older of the two packages and as such has been widely implemented.
#
#
# - 'requests' is newer and attempts to offer improved 'easy of use' relative to the older 'urllib' package.
#
#
# - Understanding how both packages work is a necessity for any Python user who wishes to interact with web pages via a Python application.
#
#
# ### The urllib library
#
# - The __urllib.request__ module facilitates the opening of a URL from within a Python application (https://docs.python.org/3/library/urllib.request.html#module-urllib.request).
#
#
# - A simple example: Access the __python.org__ main page and extract its first 300 bytes.

# %%
# load the urllib.request module
import urllib.request

# use the urlopen() function to open the python.org URL
with urllib.request.urlopen('http://www.python.org/') as f:
    # read and print the first 300 bytes found on the python.org web page
    print(f.read(300))
# Out:
# b'<!doctype html>\n<!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->\n<!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->\n<!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js"'

# %% [markdown]
# Note how urlopen() simply provides access to the underlying HTML (or XML) code: it does not parse or otherwise filter/arrange the data it is extracting.
#
#
# ### The requests library
#
# - __requests__ aims to simplify the syntax used in the __urllib__ library.
#
#
# - Some Python users say they don't see much difference when using __requests__ vs. __urllib__.
#
#
# - A simple example: Access the __github.com__ former json incident report main page and extract its text.

# %%
import requests

r = requests.get('https://github.com/timeline.json')
print (r.text)
# Out:
# {"message":"Hello there, wayfaring stranger. If you’re reading this then you probably didn’t see our blog post a couple of years back announcing that this API would go away: http://git.io/17AROg Fear not, you should be able to get what you need from the shiny new Events API instead.","documentation_url":"https://docs.github.com/v3/activity/events/#list-public-events"}

# %%
# a second simple example: Access the github.com home page and display the 
# headers found on that page
r = requests.get('https://github.com')
r.headers
# Out:
# {'server': 'GitHub.com', 'date': 'Tue, 01 Dec 2020 23:01:54 GMT', 'content-type': 'text/html; charset=utf-8', 'status': '200 OK', 'vary': 'X-PJAX, Accept-Encoding, Accept, X-Requested-With', 'etag': 'W/"ccad56026f26610b09ec4f0198062c02"', 'cache-control': 'max-age=0, private, must-revalidate', 'strict-transport-security': 'max-age=31536000; includeSubdomains; preload', 'x-frame-options': 'deny', 'x-content-type-options': 'nosniff', 'x-xss-protection': '1; mode=block', 'referrer-policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'expect-ct': 'max-age=2592000, report-uri="https://api.github.com/_private/browser/errors"', 'content-security-policy': "default-src 'none'; base-uri 'self'; block-all-mixed-content; connect-src 'self' uploads.github.com www.githubstatus.com collector.githubapp.com api.github.com github-cloud.s3.amazonaws.com github-production-repository-file-5c1aeb.s3.amazonaws.com github-production-upload-manifest-file-7fdce7.s3.amazonaws.com github-production-user-asset-6210df.s3.amazonaws.com cdn.optimizely.com logx.optimizely.com/v1/events wss://alive.github.com; font-src github.githubassets.com; form-action 'self' github.com gist.github.com; frame-ancestors 'none'; frame-src render.githubusercontent.com; img-src 'self' data: github.githubassets.com identicons.github.com collector.githubapp.com github-cloud.s3.amazonaws.com *.githubusercontent.com customer-stories-feed.github.com spotlights-feed.github.com; manifest-src 'self'; media-src github.githubassets.com; script-src github.githubassets.com; style-src 'unsafe-inline' github.githubassets.com; worker-src github.com/socket-worker.js gist.github.com/socket-worker.js", 'Content-Encoding': 'gzip', 'Set-Cookie': '_gh_sess=Imb07GP93VxjE8AB9qWIYzuyNiAIq0TI56FwFjmAXxlDxlLewz1jw6GhkisUGlwnbm4AmNJl0H1mapCLrf0zJ4R8CDPxBM4sy2bcVuod3f8DWrHtMrXrptizyJK%2BqEGzIcd17GkTirXV0NSSh7%2B1yXLXyFIN4oTThy65GRP%2B8JLvjrDCBLyIut2adaZ6GvfI2pxNj0f7s6ZNY9Er96uNCV%2BPA4IW8vFbc5AAoglGxiH35gMi1KNSNlnq%2F%2B%2FyryDD%2Fi6JZVHOKQIqwBKY1K%2Fp1A%3D%3D--4EMAy6lMPpkPTMZn--JL92IG6Jf9i%2BHNobdWoNog%3D%3D; Path=/; HttpOnly; Secure; SameSite=Lax, _octo=GH1.1.227871713.1606863722; Path=/; Domain=github.com; Expires=Wed, 01 Dec 2021 23:02:02 GMT; Secure; SameSite=Lax, logged_in=no; Path=/; Domain=github.com; Expires=Wed, 01 Dec 2021 23:02:02 GMT; HttpOnly; Secure; SameSite=Lax', 'Accept-Ranges': 'bytes', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': 'C3AF:5133:9679C:1004DC:5FC6CB6A'}

# %% [markdown]
# Note that like urlopen(), requests.get() simply provides access to the underlying HTML (or XML) code: it does not parse or otherwise filter/arrange the data it is extracting.

# %% [markdown]
# ## JSON Data
#
# - JSON (JavaScript Object Notation): One of the standard formats for transmitting data via HTTP requests (e.g., send data from a web browser to some other application).
#
#
# - JSON relies on a set of Python-esque data structures to manage content. For example, a JSON 'object' is very similar to a Python 'dict' object, JSON 'arrays' are very similar to Python lists, and JSON also allows for strings, numbers, booleans, and null items.
#
#
# - There are several pre-built Python libraries for reading and writing JSON data, including:
#
# __json__: https://docs.python.org/3/library/json.html
#
#
# __simplejson__: https://pypi.org/project/simplejson/
#
#
# __ujson__: https://pypi.org/project/ujson/
#
#
# __python-rapidjson__: https://pypi.org/project/python-rapidjson/
#
#
# - We'll use the __json__ library (comes pre-installed with a basic Python installation) for some simple examples:

# %%
# load pandas
import pandas as pd

# define a JSON string: note that we are using a Python string object to store it
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
              {"name": "Katie", "age": 38,
               "pets": ["Sixes", "Stache", "Cisco"]}]
}
"""

# %%
# import the json library
import json

# %%
# convert a json string into a Python object using the json.loads() function
result = json.loads(obj)
result
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
# note that the Python object we've created is actually a dict object
type(result)
# Out:
# dict

# %%
# convert a python object to JSON format using json.dumps()
asjson = json.dumps(result)
asjson
# Out:
# '{"name": "Wes", "places_lived": ["United States", "Spain", "Germany"], "pet": null, "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]}, {"name": "Katie", "age": 38, "pets": ["Sixes", "Stache", "Cisco"]}]}'

# %%
# note that the output of json.dumps() is a Python string object
type(asjson)
# Out:
# str

# %% [markdown]
# ### How to convert JSON data  into a Pandas Dataframe?
#
# - There is not one universally applicable approach for converting JSON data into a Pandas data frame. However, there are some built-in functions that will work with specific types of JSON data.
#
# Here's an example of how to convert a subset of the data fields contained within a list of Python dict objects to a data frame:

# %%
# create a data frame using only the 'name' and 'age' columns of the 'siblings'
# index of the 'result' dict object we create above
siblings = pd.DataFrame(result['siblings'], columns=['name', 'age'])
siblings
# Out:
#     name  age
# 0  Scott   30
# 1  Katie   38

# %% [markdown]
# ### How to read JSON data from a file?
#
# - pd.read_json() can convert properly formatted JSON data into a Pandas dataframe. The function assumes each object in a JSON array is supposed to be a row within the Pandas data frame that it creates.
#
#
# - A simple example: https://raw.githubusercontent.com/wesm/pydata-book/2nd-edition/examples/example.json

# %%
data = pd.read_json('https://raw.githubusercontent.com/wesm/pydata-book/2nd-edition/examples/example.json')
data
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# ### How to export data from a Pandas object to JSON formatting?
#
# - Use the __to_json()__ method:

# %%
# export content of a data frame to JSON format
jdata = data.to_json()
jdata
# Out:
# '{"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}'

# %%
# the resulting object is a Python string. The contents of the string
# are very similar to that of a Python dict object
type(jdata)
# Out:
# str

# %% [markdown]
# ## Reading & Writing HTML and XML Data
#
# - XML is designed for __conveying/managing__ data, i.e., its focus is on data __content__.
#
#
# - HTML is designed for __displaying__ data, i.e., its focus is on how data __looks__.
#
#
# - Python has a variety of libraries for working with XML and HTML including:
#
# __Beautiful Soup__ (https://www.crummy.com/software/BeautifulSoup/ ): A Python library that is used for extracting data from HTML and XML files/web pages. __Beautiful Soup__ by default uses Python's standard HTML parser. However, users can specify alternative parsers for __Beautiful Soup__ to use, such as __lxml__ and __html5lib__.
#
#
# __lxml__ (https://lxml.de/index.html ): A parser that can work with both XML and HTML data. __lxml__ is often used instead of the default Python HTML parser due to its processing speed.
#
#
# __html5lib__ (https://pypi.org/project/html5lib/ ): An HTML-specific parser that is often used instead of the default Python HTML parser due to its processing speed.
#
#
# ### Reading HTML Tables via Pandas
#
# Pandas provides the __read_html()__ function, which relies on components of the libraries listed above.
#
# __NOTE__: If you get an error message when trying to use the __pd.read_html()__ function, check to see whether you have the __lxml__, __BeautifulSoup__, and __html5lib__ libraries installed. If not, install them as follows:
#
# __conda install lxml__
#
# __pip install beautifulsoup4 html5lib__

# %% [markdown]
# By default, __read_html()__ (see https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_html.html) searches for __table__ tags within an HTML document and attempts to convert whatever it finds between two __tr, td, or th__ tags into a Pandas data frame.
#
# Here's an example from the PfDA textbook:
#
# https://raw.githubusercontent.com/wesm/pydata-book/2nd-edition/examples/fdic_failed_bank_list.html
#
# This HTML file has embedded within it a lengthy table containing information on U.S. banks that went bankrupt during the 2007-2009 financial crisis. The table tells us the name + location of each bank that went bankrupt, the date on which it went bankrupt, the name of the banking institution that acquired the remaining assets of the bankrupt bank, and the date on which those assets were acquired by the acquiring institution.

# %%
# example of reading an HTML file housed within the PfDA author's Github repo
tables = pd.read_html('https://raw.githubusercontent.com/wesm/pydata-book/2nd-edition/examples/fdic_failed_bank_list.html')
len(tables)
# Out:
# 1

# %%
# pd.read_html returns a Python list object
type(tables)
# Out:
# list

# %%
# the first item (and in this case, the only item) in the list is a data frame
failures = tables[0]
type(failures)
# Out:
# pandas.core.frame.DataFrame

# %%
# check the first few rows of the data frame
failures.head()
# Out:
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# 2  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016
# 3           The Bank of Fayette County      April 29, 2016  September 6, 2016
# 4  First-Citizens Bank & Trust Company      March 11, 2016      June 16, 2016

# %% [markdown]
# Now do some analysis on the extracted data: find the number of bank failures for each year:

# %%
# find the number of bank failures for each year within the data set
close_timestamps = pd.to_datetime(failures['Closing Date'])
close_timestamps.dt.year.value_counts()
# Out:
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2015      8
# 2016      5
# 2004      4
# 2001      4
# 2007      3
# 2003      3
# 2000      2
# Name: Closing Date, dtype: int64

# %% [markdown]
# ### Web Scrape Example: Using BeautifulSoup to parse an HTML web page
#
# This tutorial provides a step-by-step guide on how to use the BeautifulSoup library to extract specific content from a web page:
#
# - https://www.dataquest.io/blog/web-scraping-python-using-beautiful-soup/

# %% [markdown]
# ### Reading XML
#
# - eXtensible Markup Language (XML) supports hierarchical and nested data.
#
#
# - XML is more "generalized" than HTML, meaning it can be used for a wider variety of applications than can HTML (remember: XML = how data is __conveyed/organized__ vs. HTML = how data __appears__).
#
#
# An example from the PfDA text on how to read XML data using the __lxml__ library: NYC MTA bus and train performance data (data set located on PfDA author's GitHub repo)
#
# https://raw.githubusercontent.com/wesm/pydata-book/2nd-edition/datasets/mta_perf/Performance_MNR.xml

# %%
# load the urllib.request function so that we can use a web path with the 
# Python open() function
import urllib.request

# load the objectify() function from the lxml library
from lxml import objectify

# %%
# open the web page containing the data set: be sure to capture the 
# header info separately from the path
path, headers = urllib.request.urlretrieve('https://raw.githubusercontent.com/wesm/pydata-book/2nd-edition/datasets/mta_perf/Performance_MNR.xml')

# objectify() is then used to parse the web page
parsed = objectify.parse(open(path))

# now get a reference to the root node of the XML file
root = parsed.getroot()

# %%
# what is 'root'? It contains the root node of our file, in this case
# 'PERFORMANCE'
root
# Out:
# <Element PERFORMANCE at 0x21f91513548>

# %%
# define an empty list that will be used to store the parsed data
data = []

# define a list of XML fields that we will ignore for this particular
# data set: Note that this requires DOMAIN KNOWLEDGE - you would have
# had to explore the XML content BEFORE specifying the list of fields
# to ignore
skip_fields = ['PARENT_SEQ', 'INDICATOR_SEQ',
               'DESIRED_CHANGE', 'DECIMAL_PLACES']

# root.INDICATOR is a generator that we use to extract each <INDICATOR>
# element from the XML data
for elt in root.INDICATOR:
     # for each record, create a dict of tag names (e.g., 'YTD_ACTUAL')
    el_data = {}
    for child in elt.getchildren():
        if child.tag in skip_fields:
            continue
        el_data[child.tag] = child.pyval
    data.append(el_data)

# %%
# now check the results
perf = pd.DataFrame(data)
perf.head()
# Out:
#             AGENCY_NAME            CATEGORY  \
# 0  Metro-North Railroad  Service Indicators
# 1  Metro-North Railroad  Service Indicators
# 2  Metro-North Railroad  Service Indicators
# 3  Metro-North Railroad  Service Indicators
# 4  Metro-North Railroad  Service Indicators
#
#                                          DESCRIPTION FREQUENCY  \
# 0  Percent of commuter trains that arrive at thei...         M
# 1  Percent of commuter trains that arrive at thei...         M
# 2  Percent of commuter trains that arrive at thei...         M
# 3  Percent of commuter trains that arrive at thei...         M
# 4  Percent of commuter trains that arrive at thei...         M
#
#                          INDICATOR_NAME INDICATOR_UNIT MONTHLY_ACTUAL  \
# 0  On-Time Performance (West of Hudson)              %           96.9
# 1  On-Time Performance (West of Hudson)              %             95
# 2  On-Time Performance (West of Hudson)              %           96.9
# 3  On-Time Performance (West of Hudson)              %           98.3
# 4  On-Time Performance (West of Hudson)              %           95.8
#
#   MONTHLY_TARGET  PERIOD_MONTH  PERIOD_YEAR YTD_ACTUAL YTD_TARGET
# 0             95             1         2008       96.9         95
# 1             95             2         2008         96         95
# 2             95             3         2008       96.3         95
# 3             95             4         2008       96.8         95
# 4             95             5         2008       96.6         95

# %% [markdown]
# What if the XML data you encounter is more complicated than the MTA data we explored here? For example, consider an HTML tag, which itself is valid XML:

# %%
# loag 'StringIO()' from io to enable string buffering
from io import StringIO

# a sample HTML tag to use in our example:
tag = '<a href="http://www.google.com">Google</a>'

# buffer the 'tag' string and then parse it using 'objectify()'
root = objectify.parse(StringIO(tag)).getroot()

# %%
# what was identified as the root of 'tag'?
root
# Out:
# <Element a at 0x16905203508>

# %%
# what was found to be contained in the 'href' field?
root.get('href')
# Out:
# 'http://www.google.com'

# %%
# what text was found within the html tag?
root.text
# Out:
# 'Google'

# %% [markdown]
# ## Web Scrape Example: Pandas Tech Support Issues
#
# - An example from the PfDA text using the __request__ library: Find the last 30 issues for Pandas listed on Github:
#
# https://api.github.com/repos/pandas-dev/pandas/issues
#
#
# - Github will automatically return the requested information to us in JSON format; there is no need for us to scrape the specified web page's HTML. The automated provision of JSON serves as a form of API for interacting with the Github web site.

# %%
import requests
import pandas as pd

url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
# now convert the 'resp' object's JSON content into a list of 
# native Python objects
data = resp.json()
type(data)
# Out:
# list

# %%
# how many items are in the list object?
len(data)
# Out:
# 30

# %%
# check the content of the list
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40469',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40469/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40469/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40469/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/40469',
#   'id': 833046363,
#   'node_id': 'MDU6SXNzdWU4MzMwNDYzNjM=',
#   'number': 40469,
#   'title': 'read_excel() cannot read excel files properly with openpyxl',
#   'user': {'login': 'oakca',
#    'id': 17292790,
#    'node_id': 'MDQ6VXNlcjE3MjkyNzkw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17292790?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/oakca',
#    'html_url': 'https://github.com/oakca',
#    'followers_url': 'https://api.github.com/users/oakca/followers',
#    'following_url': 'https://api.github.com/users/oakca/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/oakca/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/oakca/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/oakca/subscriptions',
#    'organizations_url': 'https://api.github.com/users/oakca/orgs',
#    'repos_url': 'https://api.github.com/users/oakca/repos',
#    'events_url': 'https://api.github.com/users/oakca/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/oakca/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-03-16T17:35:54Z',
#   'updated_at': '2021-03-16T17:39:24Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "`pandas 1.2.3, openpyxl 3.0.7`\r\n\r\nI read an excel file with pandas via openpyxl package. It converts the number in the `'ATC'` column to a weird bitwise string. Previously I was using `xlrd(1.2.0)` instead of `openpyxl` and it was working fine:\r\n\r\n```\r\n# with openpyxl 3.0.7\r\ndf = pd.read_excel('excel_file.xlsx')\r\n\r\n>>>df['ATC']\r\n0    _x0033_40.00\r\nName: ATC, dtype: object\r\n\r\n>>>df['ATC'][0]\r\n'_x0033_40.00'\r\n```\r\n\r\n```\r\n# with xlrd 1.2.0\r\ndf = pd.read_excel('excel_file.xlsx')\r\n\r\n>>>df['ATC']\r\n0    340.0\r\nName: ATC, dtype: float64\r\n\r\n>>>df['ATC'][0]\r\n340.0\r\n```\r\n\r\nHere is the excel file if you like to check:\r\n[excel_file.xlsx](https://github.com/pandas-dev/pandas/files/6151138/excel_file.xlsx)\r\n\r\nAny work arounds? or I should keep using `xlrd`?",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40468',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40468/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40468/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40468/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/40468',
#   'id': 833017605,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTk0MDg2NzA2',
#   'number': 40468,
#   'title': 'CI: pre-commit fixups',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Related to Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/84',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/84',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/84/labels',
#    'id': 6490488,
#    'node_id': 'MDk6TWlsZXN0b25lNjQ5MDQ4OA==',
#    'number': 84,
#    'title': '1.2.4',
#    'description': 'on-merge: backport to 1.2.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 13,
#    'closed_issues': 8,
#    'state': 'open',
#    'created_at': '2021-03-01T08:32:08Z',
#    'updated_at': '2021-03-16T17:15:32Z',
#    'due_on': '2021-04-01T07:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2021-03-16T17:01:16Z',
#   'updated_at': '2021-03-16T17:18:33Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/40468',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/40468',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/40468.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/40468.patch'},
#   'body': 'Fixes 2/3 of the failures on master that im aware of.  sqlalchemy is the one left out.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40467',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40467/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40467/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40467/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/40467',
#   'id': 833003652,
#   'node_id': 'MDU6SXNzdWU4MzMwMDM2NTI=',
#   'number': 40467,
#   'title': 'BUG: run_callable is deprecated in sqlalchemy 1.4 ',
#   'user': {'login': 'jrbourbeau',
#    'id': 11656932,
#    'node_id': 'MDQ6VXNlcjExNjU2OTMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11656932?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jrbourbeau',
#    'html_url': 'https://github.com/jrbourbeau',
#    'followers_url': 'https://api.github.com/users/jrbourbeau/followers',
#    'following_url': 'https://api.github.com/users/jrbourbeau/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jrbourbeau/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jrbourbeau/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jrbourbeau/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jrbourbeau/orgs',
#    'repos_url': 'https://api.github.com/users/jrbourbeau/repos',
#    'events_url': 'https://api.github.com/users/jrbourbeau/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jrbourbeau/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 527603109,
#     'node_id': 'MDU6TGFiZWw1Mjc2MDMxMDk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dependencies',
#     'name': 'Dependencies',
#     'color': 'd93f0b',
#     'default': False,
#     'description': 'Related to pandas required and optional  dependencies'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-03-16T16:45:17Z',
#   'updated_at': '2021-03-16T16:53:19Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': "\r\n#### Code Sample, a copy-pastable example\r\n\r\nI've not yet been able to isolate the code path where `run_callable` is used\r\n\r\nhttps://github.com/pandas-dev/pandas/blob/ac3e3f71129bc9ea9ed0a27f3adcd89e367fa9af/pandas/io/sql.py#L1615-L1618\r\n\r\nHowever, it looks like several tests, for example `pandas/tests/io/test_sql.py::TestSQLApi.test_timedelta`, will trigger this warning. For instance [here's a recent CI build](https://github.com/pandas-dev/pandas/runs/2122982478#step:7:78) where a deprecation warning is being raised and actually causes the test to fail. \r\n\r\n#### Problem description\r\n\r\n[`run_callable` is deprecated in sqlalchemy 1.4](https://docs.sqlalchemy.org/en/14/core/connections.html#sqlalchemy.engine.Connection.run_callable) -- `Connection.run_callable()` should be used instead \r\n\r\n#### Expected Output\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : f2c8480af2f25efdbd803218b9d87980f416563e\r\npython           : 3.8.8.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 20.3.0\r\nVersion          : Darwin Kernel Version 20.3.0: Thu Jan 21 00:07:06 PST 2021; root:xnu-7195.81.3~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.2.3\r\nnumpy            : 1.20.1\r\npytz             : 2021.1\r\ndateutil         : 2.8.1\r\npip              : 21.0.1\r\nsetuptools       : 49.6.0.post20210108\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : 7.21.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsqlalchemy       : 1.4.0\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n```\r\n\r\n</details>\r\n",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40466',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40466/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40466/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40466/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/40466',
#   'id': 832901198,
#   'node_id': 'MDU6SXNzdWU4MzI5MDExOTg=',
#   'number': 40466,
#   'title': 'QST: No common columns to perform merge on',
#   'user': {'login': 'TWidmer46',
#    'id': 80764934,
#    'node_id': 'MDQ6VXNlcjgwNzY0OTM0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80764934?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TWidmer46',
#    'html_url': 'https://github.com/TWidmer46',
#    'followers_url': 'https://api.github.com/users/TWidmer46/followers',
#    'following_url': 'https://api.github.com/users/TWidmer46/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/TWidmer46/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/TWidmer46/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/TWidmer46/subscriptions',
#    'organizations_url': 'https://api.github.com/users/TWidmer46/orgs',
#    'repos_url': 'https://api.github.com/users/TWidmer46/repos',
#    'events_url': 'https://api.github.com/users/TWidmer46/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/TWidmer46/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'},
#    {'id': 34444536,
#     'node_id': 'MDU6TGFiZWwzNDQ0NDUzNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Usage%20Question',
#     'name': 'Usage Question',
#     'color': '0052cc',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-03-16T15:06:50Z',
#   'updated_at': '2021-03-16T15:06:50Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '```\r\nfrequency = \'monthly\'\r\nstart = \'1969-12-31\'\r\nend = \'2020-12-31\'\r\ndata = quandl.get(["ISM/MAN_PMI"], trim_start=start, trim_end=end)\r\ndata.head()\r\n```\r\nISM/MAN_PMI - PMI Date\r\n1970-01-01 48.7 1970-02-01 47.4 1970-03-01 46.9 1970-04-01 45.0 1970-05-01 47.2\r\n\r\n```\r\ndf_log = numpy.log(df / df.shift(1))\r\ndf_log.head()\r\n```\r\nAdjusted Close Date\r\n1969-12-31 NaN 1970-01-30 -0.079554 1970-02-27 0.051352 1970-03-31 0.001451 1970-04-30 -0.094842\r\n\r\n`pd.merge(df, data)`\r\nError: MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False\r\n\r\n\r\nHow chan I merge the two tables and harmonize them to:\r\n\r\n1969-12 \r\n1970-1\r\n 1970-2 \r\n1970-3 \r\n..\r\n ..',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40465',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40465/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40465/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40465/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/40465',
#   'id': 832875897,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTkzOTY2MDE0',
#   'number': 40465,
#   'title': 'TYP: stronger typing in libindex',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'mypy type annotations'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/80',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80/labels',
#    'id': 6095818,
#    'node_id': 'MDk6TWlsZXN0b25lNjA5NTgxOA==',
#    'number': 80,
#    'title': '1.3',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 107,
#    'closed_issues': 1162,
#    'state': 'open',
#    'created_at': '2020-11-11T19:05:43Z',
#    'updated_at': '2021-03-16T16:59:53Z',
#    'due_on': '2021-05-31T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-03-16T14:43:33Z',
#   'updated_at': '2021-03-16T16:45:49Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/40465',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/40465',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/40465.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/40465.patch'},
#   'body': 'and more consistent naming/args for MultiIndex engine.\r\n\r\nPreliminary before making index.pyi',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40464',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40464/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40464/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40464/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/40464',
#   'id': 832840687,
#   'node_id': 'MDU6SXNzdWU4MzI4NDA2ODc=',
#   'number': 40464,
#   'title': 'BUG: Unusual behaviour in to_parquet re-load file',
#   'user': {'login': 'DSivaji',
#    'id': 4675884,
#    'node_id': 'MDQ6VXNlcjQ2NzU4ODQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4675884?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DSivaji',
#    'html_url': 'https://github.com/DSivaji',
#    'followers_url': 'https://api.github.com/users/DSivaji/followers',
#    'following_url': 'https://api.github.com/users/DSivaji/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/DSivaji/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/DSivaji/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/DSivaji/subscriptions',
#    'organizations_url': 'https://api.github.com/users/DSivaji/orgs',
#    'repos_url': 'https://api.github.com/users/DSivaji/repos',
#    'events_url': 'https://api.github.com/users/DSivaji/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/DSivaji/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-03-16T14:10:50Z',
#   'updated_at': '2021-03-16T14:30:24Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n**Note**: Please read [this guide](https://matthewrocklin.com/blog/work/2018/02/28/minimal-bug-reports) detailing how to provide the necessary information for us to reproduce your bug.\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\n import pandas as pd\r\nprint(pd.__version__)\r\n\r\ndf = pd.DataFrame({'col1': [1,2,3,4,5], 'col2': ['s','p','d','q','r']})\r\n# check data types\r\nprint(df.dtypes)  # <-- col1 dtype: int64\r\n\r\n# convert col1 data type from int64 to object\r\ndf = df.astype({'col1': 'object'})\r\nprint(df.dtypes) # <-- col1 dtype: object\r\n\r\n# write it to a parquet file\r\ndf.to_parquet('./test.parquet', compression='gzip')\r\nre-load the dataset\r\ndf1 = pd.read_parquet('./test.parquet')\r\nprint(df1.dtypes) # <-- col1 dtype: int64 \r\n\r\n```\r\n\r\n#### Problem description\r\n\r\nIn the above code, col1 in df is converted to object before writing it to parquet file. Surprisingly, it is converted to integer after re-load. Is that an expected behaviour? I think it should preserve the data types of each column.\r\n\r\nI have seen same behaviour for float values as well.\r\n\r\n#### Expected Output\r\ncol1     object\r\ncol2    object\r\ndtype: object\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n[paste the output of ``pd.show_versions()`` here leaving a blank line after the details tag]\r\n\r\n</details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : f2c8480af2f25efdbd803218b9d87980f416563e\r\npython           : 3.7.10.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 20.3.0\r\nVersion          : Darwin Kernel Version 20.3.0: Thu Jan 21 00:07:06 PST 2021; root:xnu-7195.81.3~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : None.UTF-8\r\n\r\npandas           : 1.2.3\r\nnumpy            : 1.20.1\r\npytz             : 2021.1\r\ndateutil         : 2.8.1\r\npip              : 21.0.1\r\nsetuptools       : 49.6.0.post20210108\r\nCython           : 0.29.22\r\npytest           : 6.2.2\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.3\r\nIPython          : 7.21.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.3.4\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 3.0.0\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.6.0\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : 0.52.0\r\n\r\n",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40463',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40463/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40463/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40463/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/40463',
#   'id': 832657071,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTkzNzc5ODE0',
#   'number': 40463,
#   'title': 'BUG/TST: run and fix all arithmetic tests with+without numexpr',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 47223669,
#     'node_id': 'MDU6TGFiZWw0NzIyMzY2OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Numeric',
#     'name': 'Numeric',
#     'color': '006b75',
#     'default': False,
#     'description': 'Arithmetic, Comparison, and Logical operations'},
#    {'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'Custom testing functions or related to the test suite'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-03-16T10:40:58Z',
#   'updated_at': '2021-03-16T10:47:12Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/40463',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/40463',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/40463.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/40463.patch'},
#   'body': 'Closes #40462\r\n\r\nThis PR adds a auto-used fixture for `pandas/tests/arithmetic` that sets the `expressions._MIN_ELEMENTS` to 0, to force taking the numexpr path, even if our test data are small (which would otherwise never excercise the numexpr code path)\r\n\r\nFurther, it makes some fixes to get the tests passing with this better coverage. \r\nThe fixes are a bit quick-and-dirty, but at least already show what is needed to get things working.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40462',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40462/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40462/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40462/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/40462',
#   'id': 832557813,
#   'node_id': 'MDU6SXNzdWU4MzI1NTc4MTM=',
#   'number': 40462,
#   'title': 'BUG: operations with Offset fail for large arrays when using numexpr',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 47223669,
#     'node_id': 'MDU6TGFiZWw0NzIyMzY2OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Numeric',
#     'name': 'Numeric',
#     'color': '006b75',
#     'default': False,
#     'description': 'Arithmetic, Comparison, and Logical operations'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-03-16T08:45:19Z',
#   'updated_at': '2021-03-16T09:10:44Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'When surpassing the minimum number of elements threshold to use numexpr, the following operation starts to fail:\r\n\r\n```\r\nIn [19]: td = pd.offsets.Day(3)\r\n\r\nIn [20]: td / pd.Series([1, 2]*5000)\r\nOut[20]: \r\n0      3 days 00:00:00\r\n1      1 days 12:00:00\r\n             ...      \r\n9998   3 days 00:00:00\r\n9999   1 days 12:00:00\r\nLength: 10000, dtype: timedelta64[ns]\r\n\r\nIn [21]: td / pd.Series([1, 2]*5001)\r\n...\r\n~/miniconda3/envs/dev/lib/python3.7/site-packages/numexpr/necompiler.py in getType(a)\r\n    701     if kind == \'S\':\r\n    702         return bytes\r\n--> 703     raise ValueError("unknown type %s" % a.dtype.name)\r\n    704 \r\n    705 \r\n\r\nValueError: unknown type object\r\n```\r\n\r\nThis doesn\'t happen for a Timedelta object, I assume because of this check:\r\n\r\nhttps://github.com/pandas-dev/pandas/blob/7af47c999dc3d2782caf63fe8c42f0858937867b/pandas/core/ops/array_ops.py#L202-L203\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40461',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40461/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40461/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40461/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/40461',
#   'id': 832557474,
#   'node_id': 'MDU6SXNzdWU4MzI1NTc0NzQ=',
#   'number': 40461,
#   'title': 'BUG: inconsistency in division for scalar Offset vs series/array of Offsets',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 53181044,
#     'node_id': 'MDU6TGFiZWw1MzE4MTA0NA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Frequency',
#     'name': 'Frequency',
#     'color': '0052cc',
#     'default': False,
#     'description': 'DateOffsets'},
#    {'id': 47223669,
#     'node_id': 'MDU6TGFiZWw0NzIyMzY2OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Numeric',
#     'name': 'Numeric',
#     'color': '006b75',
#     'default': False,
#     'description': 'Arithmetic, Comparison, and Logical operations'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-03-16T08:44:52Z',
#   'updated_at': '2021-03-16T08:44:52Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'When dividing a scalar Offset with a numeric series, we get a timedelta64 series. But when dividing a Series of Offsets, we preserve the offsets.\r\n\r\n```\r\nIn [26]: td = pd.offsets.Day(3)\r\n\r\nIn [27]: td / pd.Series([1, 2])\r\nOut[27]: \r\n0   3 days 00:00:00\r\n1   1 days 12:00:00\r\ndtype: timedelta64[ns]\r\n\r\nIn [28]: pd.Series([td, td]) / pd.Series([1, 2])\r\nOut[28]: \r\n0      <3 * Days>\r\n1    <36 * Hours>\r\ndtype: object\r\n```\r\n\r\nAlso "scalar / scalar" operation gives an Offset.  \r\n\r\n\r\ncc @jbrockmendel ',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40460',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40460/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40460/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40460/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/40460',
#   'id': 832546863,
#   'node_id': 'MDU6SXNzdWU4MzI1NDY4NjM=',
#   'number': 40460,
#   'title': 'QST: Support of SQLAlchemy 2.0 in Pandas',
#   'user': {'login': 'mickaelandrieu',
#    'id': 1247388,
#    'node_id': 'MDQ6VXNlcjEyNDczODg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1247388?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mickaelandrieu',
#    'html_url': 'https://github.com/mickaelandrieu',
#    'followers_url': 'https://api.github.com/users/mickaelandrieu/followers',
#    'following_url': 'https://api.github.com/users/mickaelandrieu/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mickaelandrieu/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mickaelandrieu/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mickaelandrieu/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mickaelandrieu/orgs',
#    'repos_url': 'https://api.github.com/users/mickaelandrieu/repos',
#    'events_url': 'https://api.github.com/users/mickaelandrieu/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mickaelandrieu/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 527603109,
#     'node_id': 'MDU6TGFiZWw1Mjc2MDMxMDk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dependencies',
#     'name': 'Dependencies',
#     'color': 'd93f0b',
#     'default': False,
#     'description': 'Related to pandas required and optional  dependencies'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-03-16T08:30:01Z',
#   'updated_at': '2021-03-16T16:03:44Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': 'After search in Stackoverflow and in your open and closed issues, I can\'t find any information about the support of SQL Alchemy 2.0 using `pd.to_sql()`\r\n\r\n---\r\n\r\n#### Question about pandas\r\n\r\nAn exemple is better than a talk.\r\n\r\n```python\r\nfrom sqlalchemy import create_engine, MetaData, Table, Column, String, Integer\r\nimport pandas as pd\r\n\r\n# Table creation\r\nengine = create_engine(connection_string, echo=True, future=True) # This uses SQL Alchemy 2.0 API\r\nmetadata = MetaData()\r\ncategory = Table(\r\n        \'category\',\r\n        metadata,\r\n        Column(\'id\', Integer, primary_key = True),\r\n        Column(\'name\', String(128), nullable = False),\r\n        Column(\'slug\', String(128), nullable = False)\r\n    )\r\n\r\ncategory.create(engine, checkfirst=True)\r\n\r\n## Insert using pandas => FAIL\r\ncategories = pd.DataFrame([{\'id\' : 1, \'slug\': \'test\', \'name\': \'Test\'}])\r\ncategories.to_sql(\'category\', engine, index=False)\r\n```\r\n\r\nThis is the error I get from the CLI output :\r\n\r\n```\r\n  File "e:\\Projects\\test\\database.py", line 127, in populate_category_table\r\n    categories.to_sql(\'category\', engine, index=False)\r\n  File "E:\\Projects\\test\\env\\lib\\site-packages\\pandas\\core\\generic.py", \r\nline 2779, in to_sql\r\n    sql.to_sql(\r\n  File "E:\\Projects\\test\\env\\lib\\site-packages\\pandas\\io\\sql.py", line 590, in to_sql\r\n    pandas_sql.to_sql(\r\n  File "E:\\Projects\\test\\env\\lib\\site-packages\\pandas\\io\\sql.py", line 1392, in to_sql\r\n    table.create()\r\n  File "E:\\Projects\\test\\env\\lib\\site-packages\\pandas\\io\\sql.py", line 722, in create\r\n    if self.exists():\r\n  File "E:\\Projects\\test\\env\\lib\\site-packages\\pandas\\io\\sql.py", line 709, in exists\r\n    return self.pd_sql.has_table(self.name, self.schema)\r\n  File "E:\\Projects\\test\\env\\lib\\site-packages\\pandas\\io\\sql.py", line 1429, in has_table\r\n    return self.connectable.run_callable(\r\n  File "E:\\Projects\\test\\env\\lib\\site-packages\\sqlalchemy\\future\\engine.py", line 335, in _not_implemented\r\n    raise NotImplementedError(\r\nNotImplementedError: This method is not implemented for SQLAlchemy 2.0.\r\n```\r\n\r\nFor information about the version of every dependency :\r\n\r\n````\r\n$ ./env/Scripts/pip list\r\nPackage         Version\r\n--------------- ---------\r\nbeautifulsoup4  4.9.3\r\ncertifi         2020.12.5\r\nchardet         4.0.0\r\nesprima         4.0.1\r\ngreenlet        1.0.0\r\nidna            2.10\r\nmysqlclient     2.0.3\r\nnumpy           1.20.1\r\npandas          1.2.3\r\npatreon         0.5.0\r\npip             21.0.1\r\npython-dateutil 2.8.1\r\npytz            2021.1\r\nrequests        2.25.1\r\nsetuptools      49.2.1\r\nsix             1.15.0\r\nsoupsieve       2.2\r\nSQLAlchemy      1.4.0\r\nurllib3         1.26.3\r\n````\r\n\r\nIs there a workaround right now or should I avoid using pandas to insert the data into my database ?\r\n\r\nRegards,\r\n\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40459',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40459/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40459/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40459/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/40459',
#   'id': 832536952,
#   'node_id': 'MDU6SXNzdWU4MzI1MzY5NTI=',
#   'number': 40459,
#   'title': 'DOC: pandas.Series.str.replace has pandas.DataFrame.str.replace examples',
#   'user': {'login': 'dgokeeffe',
#    'id': 17697537,
#    'node_id': 'MDQ6VXNlcjE3Njk3NTM3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17697537?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dgokeeffe',
#    'html_url': 'https://github.com/dgokeeffe',
#    'followers_url': 'https://api.github.com/users/dgokeeffe/followers',
#    'following_url': 'https://api.github.com/users/dgokeeffe/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dgokeeffe/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dgokeeffe/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dgokeeffe/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dgokeeffe/orgs',
#    'repos_url': 'https://api.github.com/users/dgokeeffe/repos',
#    'events_url': 'https://api.github.com/users/dgokeeffe/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dgokeeffe/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-03-16T08:16:44Z',
#   'updated_at': '2021-03-16T08:16:44Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '#### Location of the documentation\r\n\r\nhttps://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.replace.html\r\n\r\n#### Documentation problem\r\n\r\nThe documentation has DataFrame examples and not those related to Series\r\n\r\n#### Suggested fix for documentation\r\n\r\nGive examples related to Series.\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40458',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40458/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40458/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40458/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/40458',
#   'id': 832379780,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTkzNTQ2NjMx',
#   'number': 40458,
#   'title': 'TST: csv parser segfaulting on malformed input.',
#   'user': {'login': 'ahawryluk',
#    'id': 50434302,
#    'node_id': 'MDQ6VXNlcjUwNDM0MzAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50434302?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ahawryluk',
#    'html_url': 'https://github.com/ahawryluk',
#    'followers_url': 'https://api.github.com/users/ahawryluk/followers',
#    'following_url': 'https://api.github.com/users/ahawryluk/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ahawryluk/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ahawryluk/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ahawryluk/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ahawryluk/orgs',
#    'repos_url': 'https://api.github.com/users/ahawryluk/repos',
#    'events_url': 'https://api.github.com/users/ahawryluk/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ahawryluk/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 47229171,
#     'node_id': 'MDU6TGFiZWw0NzIyOTE3MQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20CSV',
#     'name': 'IO CSV',
#     'color': '5319e7',
#     'default': False,
#     'description': None},
#    {'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'Custom testing functions or related to the test suite'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/80',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80/labels',
#    'id': 6095818,
#    'node_id': 'MDk6TWlsZXN0b25lNjA5NTgxOA==',
#    'number': 80,
#    'title': '1.3',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 107,
#    'closed_issues': 1162,
#    'state': 'open',
#    'created_at': '2020-11-11T19:05:43Z',
#    'updated_at': '2021-03-16T16:59:53Z',
#    'due_on': '2021-05-31T07:00:00Z',
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2021-03-16T03:40:50Z',
#   'updated_at': '2021-03-16T17:16:29Z',
#   'closed_at': None,
# ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40435',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40435/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40435/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40435/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/40435',
#   'id': 831265441,
#   'node_id': 'MDU6SXNzdWU4MzEyNjU0NDE=',
#   'number': 40435,
#   'title': 'BUG: append/concat for dataframes with DatetimeIndex having same timezone value but different tz classes results in change of Index type to generic Index (in place of DatetimeIndex)',
#   'user': {'login': 'avnishbm',
#    'id': 12374280,
#    'node_id': 'MDQ6VXNlcjEyMzc0Mjgw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12374280?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/avnishbm',
#    'html_url': 'https://github.com/avnishbm',
#    'followers_url': 'https://api.github.com/users/avnishbm/followers',
#    'following_url': 'https://api.github.com/users/avnishbm/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/avnishbm/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/avnishbm/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/avnishbm/subscriptions',
#    'organizations_url': 'https://api.github.com/users/avnishbm/orgs',
#    'repos_url': 'https://api.github.com/users/avnishbm/repos',
#    'events_url': 'https://api.github.com/users/avnishbm/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/avnishbm/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-03-14T21:30:51Z',
#   'updated_at': '2021-03-14T21:30:51Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [ Y] I have checked that this issue has not already been reported.\r\n\r\n- [Y ] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ Y] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n**Note**: Please read [this guide](https://matthewrocklin.com/blog/work/2018/02/28/minimal-bug-reports) detailing how to provide the necessary information for us to reproduce your bug.\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport pandas as pd \r\nfrom datetime import datetime, timedelta\r\nimport dateutil\r\nimport psycopg2\r\n\r\n\r\n#### Same time zone but using different tz classes though with same offset\r\nIST_tz_offset = dateutil.tz.tz.tzoffset(None, 19800) # offset in seconds, 19800s equals 330 mins\r\nIST_tz_postgres_offset = psycopg2.tz.FixedOffsetTimezone(offset=330, name=None) # it is in mins\r\n\r\n# create list of lists\r\ndata1 = [[pd.Timestamp(\'2021-03-14 06:00:00\', tz = IST_tz_offset), 15], [pd.Timestamp(\'2021-03-14 06:00:00\', tz = IST_tz_offset) - timedelta(hours=1), 14], [pd.Timestamp(\'2021-03-14 06:00:00\', tz = IST_tz_offset) - timedelta(hours=2), 12]] \r\n# Create the pandas DataFrame \r\ndf1 = pd.DataFrame(data1, columns = [\'datetime\', \'value\']) \r\ndf1.set_index(\'datetime\', inplace = True)\r\n\r\n# initialize list of lists \r\ndata2 = [[pd.Timestamp(\'2021-03-14 06:00:00\', tz = IST_tz_postgres_offset) - timedelta(days=1), 10], [pd.Timestamp(\'2021-03-14 06:00:00\', tz = IST_tz_postgres_offset) - timedelta(days = 1, hours=1), 9], [pd.Timestamp(\'2021-03-14 06:00:00\', tz = IST_tz_postgres_offset) - timedelta(days = 1, hours=2), 8]] \r\n# Create the pandas DataFrame \r\ndf2 = pd.DataFrame(data2, columns = [\'datetime\', \'value\']) \r\ndf2.set_index(\'datetime\', inplace = True)\r\n\r\nprint ("Same timezones but different tz classes: df1.index[0] = {}, df2.index[0] = {}".format(df1.index[0], df2.index[0]))\r\nprint ("Same timezones but different tz classes: type(df1.index) = {}, type(df2.index) = {}".format(type(df1.index), type(df2.index)))\r\nappended_df = df2.append(df1)\r\nconcatenated_df = pd.concat([df2, df1])\r\nprint ("Same timezones but different tz classes: type(appended_df.index) = {}, type(concatenated_df.index) = {}\\n".format(type(appended_df.index), type(concatenated_df.index)))\r\n\r\n```\r\n\r\n#### Problem description\r\n\r\nHave hit this issue when trying to append/concat dataframes with DatetimeIndex index types, where the data comes from different sources i.e. in this case, from postgres db and a data providers, and though the data has the same timezone (Asia/Kolkata), as can be seen from sample data printed in code, post append/concat the index type gets converted to "Index" in place of DatetimeIndex. This further caused an issue at our end, for things like resample() which in turn required DatetimeIndex type. The only different in the Timestamp data that we found was that their tz datatype was different even though both had the same offset value (19800 seconds or 330 mins, both being equal).\r\n\r\nSample data when printed:\r\nSame timezones but different tz classes: df1.index[0] = 2021-03-14 06:00:00+05:30, df2.index[0] = 2021-03-13 06:00:00+05:30 \r\n\r\n#### Expected Output\r\nIn this case, since the timezone was essentially the same for the data, would have expected that the datatype for the index should not have changed after append or concat. It should have remained as DatetimeIndex type.\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 7d32926db8f7541c356066dcadabf854487738de\r\npython           : 3.8.2.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 20.3.0\r\nVersion          : Darwin Kernel Version 20.3.0: Thu Jan 21 00:07:06 PST 2021; root:xnu-7195.81.3~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : littl ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40432',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40432/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40432/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40432/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/40432',
#   'id': 831212622,
#   'node_id': 'MDU6SXNzdWU4MzEyMTI2MjI=',
#   'number': 40432,
#   'title': 'ENH: Add an option to json_normalize() to protect nested object(s) against flattening',
#   'user': {'login': 'swiss-knight',
#    'id': 19967599,
#    'node_id': 'MDQ6VXNlcjE5OTY3NTk5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19967599?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/swiss-knight',
#    'html_url': 'https://github.com/swiss-knight',
#    'followers_url': 'https://api.github.com/users/swiss-knight/followers',
#    'following_url': 'https://api.github.com/users/swiss-knight/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/swiss-knight/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/swiss-knight/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/swiss-knight/subscriptions',
#    'organizations_url': 'https://api.github.com/users/swiss-knight/orgs',
#    'repos_url': 'https://api.github.com/users/swiss-knight/repos',
#    'events_url': 'https://api.github.com/users/swiss-knight/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/swiss-knight/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-03-14T17:32:03Z',
#   'updated_at': '2021-03-14T17:32:03Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '#### Is your feature request related to a problem?\r\n\r\nNot really. I simply wish I could use pandas to [protect](https://stackoverflow.com/questions/66611187/protect-a-nested-object-against-flattening-when-using-pandas-json-normalize) a nested structure / object / dict against flattening when using [pd.json_normalize()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.json_normalize.html) on a JSON object, for example an API response.\r\n\r\n#### Describe the solution you\'d like\r\n\r\nSomething like this (see below for a complete example):  \r\n```python\r\ndf = pd.DataFrame(pd.json_normalize(data, protect="foo.bar.baz"))\r\n\r\n# or this, if there isn\'t more than 1 object with the same name \r\n# (or even if there are more than one object with the same name, it should apply to all of them) :\r\ndf = pd.DataFrame(pd.json_normalize(data, protect="baz"))\r\n```\r\n\r\n#### API breaking implications\r\n\r\nI have no detailed idea what this could/would break.\r\n\r\n#### Describe alternatives you\'ve considered\r\n\r\nMy current workaround is to duplicate the DataFrame; building one without normalizing, the other with. Keeping only the protected column(s) of the one which hasn\'t been normalized and concatenating them to the other. Remove redundant columns on the final DataFrame.\r\n\r\n#### Additional context\r\n\r\nHere\'s a dummy example:    \r\n\r\n```python\r\nimport pandas as pd\r\n\r\nresponse = \'\'\'\r\n    {\r\n      "results": [\r\n        {\r\n          "geometry": {\r\n            "type": "Polygon",\r\n            "crs": 4326,\r\n            "coordinates": \r\n              [[\r\n                  [6.0, 49.0],\r\n                  [6.0, 40.0],\r\n                  [7.0, 40.0],\r\n                  [7.0, 49.0],\r\n                  [6.0, 49.0]\r\n              ]]\r\n          },\r\n          "attribute": "layer.metadata",\r\n          "bbox": [6, 40, 7, 49],\r\n          "featureName": "Coniferous_Trees",\r\n          "layerName": "State_Forests",\r\n          "type": "Feature",\r\n          "id": "17",\r\n          "properties": {\r\n            "resolution": "100",\r\n            "Year": "2020",\r\n            "label": "Coniferous"\r\n          }\r\n        }\r\n      ]\r\n    }\r\n\'\'\'\r\n\r\ndata = json.loads(response)[\'results\']\r\ndf = pd.DataFrame(pd.json_normalize(data))\r\n```\r\nThen:\r\n```python\r\n>>> print(df.columns)\r\nIndex([\'attribute\', \'bbox\', \'featureName\', \'layerName\', \'type\', \'id\',\r\n       \'geometry.type\', \'geometry.crs\', \'geometry.coordinates\', # <-- the geometry has been flattened along all the other objects\r\n       \'properties.resolution\', \'properties.Year\', \'properties.label\'],\r\n      dtype=\'object\')\r\n```\r\n\r\nDesired behaviour:    \r\n```python\r\ndf = pd.DataFrame(pd.json_normalize(data, protect="results.geometry"))\r\n```\r\n\r\nwhich would lead to:\r\n```\r\n>>> print(df.columns)\r\n\r\nIndex([\'attribute\', \'bbox\', \'featureName\', \'layerName\', \'type\', \'id\',\r\n       \'geometry\', # <-- the geometry element has been protected, it stays as a nested JSON structure in its own column in the DataFrame.\r\n       \'properties.resolution\',  \'properties.Year\', \'properties.label\'],\r\n      dtype=\'object\')\r\n```\r\n\r\nThanks for reading.\r\n',
#   'performed_via_github_app': None}]

# %%
# let's look at the data type of the first item in the list
type(data[0])
# Out:
# dict

# %%
# view the content of that dict object
data[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40469',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40469/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40469/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40469/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/issues/40469',
#  'id': 833046363,
#  'node_id': 'MDU6SXNzdWU4MzMwNDYzNjM=',
#  'number': 40469,
#  'title': 'read_excel() cannot read excel files properly with openpyxl',
#  'user': {'login': 'oakca',
#   'id': 17292790,
#   'node_id': 'MDQ6VXNlcjE3MjkyNzkw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/17292790?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/oakca',
#   'html_url': 'https://github.com/oakca',
#   'followers_url': 'https://api.github.com/users/oakca/followers',
#   'following_url': 'https://api.github.com/users/oakca/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/oakca/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/oakca/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/oakca/subscriptions',
#   'organizations_url': 'https://api.github.com/users/oakca/orgs',
#   'repos_url': 'https://api.github.com/users/oakca/repos',
#   'events_url': 'https://api.github.com/users/oakca/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/oakca/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'labels': [],
#  'state': 'open',
#  'locked': False,
#  'assignee': None,
#  'assignees': [],
#  'milestone': None,
#  'comments': 0,
#  'created_at': '2021-03-16T17:35:54Z',
#  'updated_at': '2021-03-16T17:39:24Z',
#  'closed_at': None,
#  'author_association': 'NONE',
#  'active_lock_reason': None,
#  'body': "`pandas 1.2.3, openpyxl 3.0.7`\r\n\r\nI read an excel file with pandas via openpyxl package. It converts the number in the `'ATC'` column to a weird bitwise string. Previously I was using `xlrd(1.2.0)` instead of `openpyxl` and it was working fine:\r\n\r\n```\r\n# with openpyxl 3.0.7\r\ndf = pd.read_excel('excel_file.xlsx')\r\n\r\n>>>df['ATC']\r\n0    _x0033_40.00\r\nName: ATC, dtype: object\r\n\r\n>>>df['ATC'][0]\r\n'_x0033_40.00'\r\n```\r\n\r\n```\r\n# with xlrd 1.2.0\r\ndf = pd.read_excel('excel_file.xlsx')\r\n\r\n>>>df['ATC']\r\n0    340.0\r\nName: ATC, dtype: float64\r\n\r\n>>>df['ATC'][0]\r\n340.0\r\n```\r\n\r\nHere is the excel file if you like to check:\r\n[excel_file.xlsx](https://github.com/pandas-dev/pandas/files/6151138/excel_file.xlsx)\r\n\r\nAny work arounds? or I should keep using `xlrd`?",
#  'performed_via_github_app': None}

# %%
# what's in the 'title' component of the dict?
data[0]['title']
# Out:
# 'read_excel() cannot read excel files properly with openpyxl'

# %%
# now convert some of the extracted JSON data into a data frame: in this
# example we are extracting the 'number', 'title', 'labels' and 'state'
# components of the dict object
issues = pd.DataFrame(data, columns=['number', 'title',
                                     'labels', 'state'])
issues
# Out:
#     number                                              title  \
# 0    40469  read_excel() cannot read excel files properly ...
# 1    40468                              CI: pre-commit fixups
# 2    40467  BUG: run_callable is deprecated in sqlalchemy ...
# 3    40466         QST: No common columns to perform merge on
# 4    40465                   TYP: stronger typing in libindex
# 5    40464  BUG: Unusual behaviour in to_parquet re-load file
# 6    40463  BUG/TST: run and fix all arithmetic tests with...
# 7    40462  BUG: operations with Offset fail for large arr...
# 8    40461  BUG: inconsistency in division for scalar Offs...
# 9    40460           QST: Support of SQLAlchemy 2.0 in Pandas
# 10   40459  DOC: pandas.Series.str.replace has pandas.Data...
# 11   40458    TST: csv parser segfaulting on malformed input.
# 12   40456  REF: back DatetimeBlock, TimedeltaBlock by DTA...
# 13   40455  TYP: stubs for reshape, ops, ops_dispatch, has...
# 14   40454  BUG: test_table_method_rolling_methods segfaul...
# 15   40453  CLN: make `cell_context` DefaultDict like `ctx...
# 16   40452                                   TYP: fix ignores
# 17   40451  BUG/API: Index.__new__ match Series datetime i...
# 18   40450          Fix StringArray.astype for category dtype
# 19   40446  BUG: groupby fast_apply vs python apply handle...
# 20   40445  PERF: no need to check for DataFrame in pandas...
# 21   40444                REF: move roperators to pandas.core
# 22   40443  BUG: Memory leak in json encoding for time rel...
# 23   40442  BUG: read_excel fails with multirow headers if...
# 24   40441  [ArrayManager] DataFrame constructor from ndarray
# 25   40440  BUG: Unexpected behavior of setting item to Da...
# 26   40437       ENH: `escape` html argument in Styler.format
# 27   40436  BUG: DataFrame.query doesn't support equals or...
# 28   40435  BUG: append/concat for dataframes with Datetim...
# 29   40432  ENH: Add an option to json_normalize() to prot...
#
#                                                labels state
# 0                                                  []  open
# 1   [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 2   [{'id': 527603109, 'node_id': 'MDU6TGFiZWw1Mjc...  open
# 3   [{'id': 1954720290, 'node_id': 'MDU6TGFiZWwxOT...  open
# 4   [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 5   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 6   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 7   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 8   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 9   [{'id': 527603109, 'node_id': 'MDU6TGFiZWw1Mjc...  open
# 10  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 11  [{'id': 47229171, 'node_id': 'MDU6TGFiZWw0NzIy...  open
# 12                                                 []  open
# 13  [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 14  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 15                                                 []  open
# 16  [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 17                                                 []  open
# 18  [{'id': 32815646, 'node_id': 'MDU6TGFiZWwzMjgx...  open
# 19  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 20                                                 []  open
# 21  [{'id': 47223669, 'node_id': 'MDU6TGFiZWw0NzIy...  open
# 22  [{'id': 49379259, 'node_id': 'MDU6TGFiZWw0OTM3...  open
# 23  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 24  [{'id': 1465286368, 'node_id': 'MDU6TGFiZWwxND...  open
# 25  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 26  [{'id': 1728592794, 'node_id': 'MDU6TGFiZWwxNz...  open
# 27  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 28  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 29  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open

# %% [markdown]
# ## Web Scrape Example: Using Selenium to scrape a dynamically loaded web page
#
# __Selenium__ is a software library that enables the scraping of __web pages whose content is loaded dynamically__ (i.e., as we interact with them) as opposed to "static" web pages that have fixed content for the duration of our page visit.
#
# Scraping web pages that are loaded dynamically can be challenging. However, the Selenium package makes it possible to successfully extract content from such pages via a relatively easy-to-understand set of constructs.
#
# Using Selenium's functionality, you can use Python code to dynamically navigate (or "interact with") a web site via your Python code and then extract information from your web browser as the browser responds to the web page navigation instructions sent to it via your Python code.
#
# - https://towardsdatascience.com/step-by-step-web-scraping-project-using-selenium-in-python-3be887e6e35c

# %% [markdown]
# ## Interacting with Web API's
#
# - Many websites provide publicly available API's that allow users to either access data feeds or download web page content via JSON, XML, HTML, or some other format.
#
#
# - These API's can be a great tool for purposes of collecting all sorts of data for further analysis.
#
#
# - Unfortunately, the vast majority of websites __DO NOT__ provide Web API's.
#
#
# - Get started by searching the website for Web API information.
#
#
# - If the site offers a Web API, most likely you will need to sign up for a Web API Key code (a unique identifier that enables your personal access to the content of the web site.
#
#
# - Then, follow the instructions shown on the website for guidance on how to construct requests for specific information via their proprietary API.

# %% [markdown]
# ## Web API Example:  Fetch the live weather report for a given city
#
# - Get the current temperature, wind speed, description and sky conditions for a given city from __openweathermap.org__ via their free API: https://openweathermap.org/current
#
#
# - Sourced from https://www.w3resource.com/python-exercises/web-scraping/web-scraping-exercise-21.php
#
#
# Note the use of an __openweathermap.org__ API key:
#
#         'APPID =b35975e18dc93725acb092f7272cc6b8'

# %%
import requests
from pprint import pprint

def weather_data(query):
    # submit our request via the openweathermap.org api
    # note the inclusion of the required API key
    res=requests.get('http://api.openweathermap.org/data/2.5/weather?'+query+
                     '&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric');
    return res.json();


def print_weather(result,city):
    print("{}'s temperature: {}°C ".format(city,result['main']['temp']))
    print("Wind speed: {} m/s".format(result['wind']['speed']))
    print("Description: {}".format(result['weather'][0]['description']))
    print("Weather: {}".format(result['weather'][0]['main']))


def main():
    city=input('Enter the city:')
    print()
    try:
      query='q='+city;
      w_data=weather_data(query);
      print_weather(w_data, city)
      print()
    except:
      print('City name not found...')
if __name__=='__main__':
    main()
# Out:
# Enter the city:playa del carmen, mexico
#
# playa del carmen, mexico's temperature: 28.65°C
# Wind speed: 6.69 m/s
# Description: broken clouds
# Weather: Clouds

# %% [markdown]
# ## Case Study: Scraping 'Apartments.com' for the name, address, description, and prices of available apartments
#
# https://towardsdatascience.com/an-introduction-to-web-scraping-with-python-bc9563fe8860
